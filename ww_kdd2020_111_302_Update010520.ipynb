# %% [markdown]
# <a href="https://colab.research.google.com/github/CalculatedContent/ww-colab/blob/master/ww_kdd2020_111_302_Update010520.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Setup**

# %%
import pandas as pd
import numpy as np
import time
import datetime as dt
import itertools
import os
import statsmodels.api as sm
import matplotlib.pyplot as plt
from google.colab import files #Google colab ONLY

# %%
istart = 111
iend = istart+191

# %%
## If export the output to Google Drive (colab ONLY) --> Optional
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import sys
path = '/content/drive/My Drive/kdd2020_cv'
sys.path.append(path)

if not os.path.exists(path): #if the path does not already exists, create one
   # !mkdir "$path"

# !ls "$path"

# %%
# !pip install weightwatcher #install from source
#!pip install powerlaw #needed if install ww from local

# %%
import weightwatcher as ww

# Suppress the powerlaw package warnings
# "powerlaw.py:700: RuntimeWarning: divide by zero encountered in true_divide"
# "powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide"
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# crea
import logging
logger = logging.getLogger("imported_module")
logger.setLevel(logging.CRITICAL)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %% [markdown]
# # **PyTorchCV Models**
#
# ## These cells need to be rerun multiple times to get all the data![alt text](https://)

# %% [markdown]
# ### **1. Analyze all models in Pytorchcv**

# %%
# !pip install pytorchcv

# %%
## Check storage
#import subprocess
#p = subprocess.Popen('df -h', shell=True, stdout=subprocess.PIPE)
#print(str(p.communicate()[0], 'utf-8'))

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model
import torch

import pytorchcv
import pytorchcv.models.model_store

modelnames = pytorchcv.models.model_store._model_sha1.keys()
modelnames = list(modelnames)
print('{} models to examine'.format(len(modelnames)))
# Out:
# 487 models to examine

# %%
## If you have record models that could not be found
# this_models = pd.read_excel('notfound.xlsx')[0].tolist()
# len(this_models[1:])

# %% [markdown]
# # Reun upto and including this cell  until all data is available

# %%
## Set up the data to start storing
data = {} #Store main model data
notfound = []
ww_error = []
print("istart = {}".format(istart), "and iend = {}".format(iend), 
      "\nThe code in next block will run model from #{} to #{}".format(istart+1, iend))
# Out:
# istart = 111 and iend = 302
# The code in next block will run model from #112 to #302

# %%
## Takes about 10-15 hours to run 400+ models as of 12/31/2019

ss = time.time()
i = 0
for modelname in modelnames[istart:iend]: 
    print(modelname)
    try:
        s = time.time()
        model = ptcv_get_model(modelname, pretrained=True)

    except:
        notfound.append(modelname)
        e = time.time()
        print("{} not found".format(modelname))
        print('--------------------------------------------------------')
        i += 1
        continue

    try:
        watcher = ww.WeightWatcher(model=model, logger=logger)
        results = watcher.analyze(alphas = True, spectralnorms=True, softranks=True, mp_fit = True, normalize = False)
        e = time.time()
        
        data[modelname]=watcher.get_summary()
        
        print('time spent is {}'.format((e-s)/60.))
        print('--------------------------------------------------------')
        
    except:
        ww_error.append(modelname)
        e = time.time()
        print("Error in weightwatcher operation for {}".format(modelname))
        print('--------------------------------------------------------')

    #Export/backup the results every 1 hour runtime or every 50 models  
    if ((e - ss) > 60*60) or ((i - istart)%25 == 0): 
      
        ddf = pd.DataFrame.from_dict(data).transpose()
        ddf.to_excel(path + '/data_{}-{}_{}.xlsx'.format(istart, i, dt.date.today()))
        
        ss = time.time()
        
        #try:
        #    !rm -rf /root/.torch/models #clean the memory
        #except:
        #    pass
          
    if i + istart >= iend: #Export when all models are finished
      
        ddf = pd.DataFrame.from_dict(data).transpose()
        ddf.to_excel(path + '/data_{}-{}_{}.xlsx'.format(istart, i, dt.date.today()))
        
        # break

    i += 1
    
ddf = pd.DataFrame.from_dict(data).transpose()
ddf.to_excel(path + '/data_{}-{}_{}.xlsx'.format(istart, i, dt.date.today()))
# Out:
# bagnet9
# Downloading /root/.torch/models/bagnet9-2961-cab11792.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.255/bagnet9-2961-cab11792.pth.zip...
# time spent is 1.340890141328176
# --------------------------------------------------------
# bagnet17
# Downloading /root/.torch/models/bagnet17-1884-6b2a100f.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.255/bagnet17-1884-6b2a100f.pth.zip...
# time spent is 1.4535576740900675
# --------------------------------------------------------
# bagnet33
# Downloading /root/.torch/models/bagnet33-1301-4f17b6e8.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.255/bagnet33-1301-4f17b6e8.pth.zip...
# time spent is 1.7230344414710999
# --------------------------------------------------------
# dla34
# Downloading /root/.torch/models/dla34-0794-04698d78.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.202/dla34-0794-04698d78.pth.zip...
# time spent is 2.9230188012123106
# --------------------------------------------------------
# dla46c
# Downloading /root/.torch/models/dla46c-1323-efcd3636.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.282/dla46c-1323-efcd3636.pth.zip...
# time spent is 0.5190419832865397
# --------------------------------------------------------
# dla46xc
# Downloading /root/.torch/models/dla46xc-1269-00d3754a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.293/dla46xc-1269-00d3754a.pth.zip...
# time spent is 0.3411873618761698
# --------------------------------------------------------
# dla60
# Downloading /root/.torch/models/dla60-0669-b2cd6e51.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.202/dla60-0669-b2cd6e51.pth.zip...
# time spent is 3.1512723088264467
# --------------------------------------------------------
# dla60x
# Downloading /root/.torch/models/dla60x-0598-88547d3f.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.202/dla60x-0598-88547d3f.pth.zip...
# time spent is 1.8290274103482564
# --------------------------------------------------------
# dla60xc
# Downloading /root/.torch/models/dla60xc-1091-0f6381f3.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.289/dla60xc-1091-0f6381f3.pth.zip...
# time spent is 0.4466324210166931
# --------------------------------------------------------
# dla102
# Downloading /root/.torch/models/dla102-0605-11df1322.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.202/dla102-0605-11df1322.pth.zip...
# time spent is 5.082084135214488
# --------------------------------------------------------
# dla102x
# Downloading /root/.torch/models/dla102x-0577-58331655.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.202/dla102x-0577-58331655.pth.zip...
# time spent is 2.886384165287018
# --------------------------------------------------------
# dla102x2
# Downloading /root/.torch/models/dla102x2-0536-07936111.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.202/dla102x2-0536-07936111.pth.zip...
# time spent is 3.0756421208381655
# --------------------------------------------------------
# dla169
# Downloading /root/.torch/models/dla169-0566-ae0c6a82.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.202/dla169-0566-ae0c6a82.pth.zip...
# time spent is 8.2434978445371
# --------------------------------------------------------
# fishnet150
# Downloading /root/.torch/models/fishnet150-0604-f5af4873.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.168/fishnet150-0604-f5af4873.pth.zip...
# time spent is 4.546617805957794
# --------------------------------------------------------
# espnetv2_wd2
# Downloading /root/.torch/models/espnetv2_wd2-2015-d234781f.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.238/espnetv2_wd2-2015-d234781f.pth.zip...
# time spent is 0.2741342226664225
# --------------------------------------------------------
# espnetv2_w1
# Downloading /root/.torch/models/espnetv2_w1-1345-550d5422.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.238/espnetv2_w1-1345-550d5422.pth.zip...
# time spent is 0.3518532752990723
# --------------------------------------------------------
# espnetv2_w5d4
# Downloading /root/.torch/models/espnetv2_w5d4-1218-85d97b2b.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.238/espnetv2_w5d4-1218-85d97b2b.pth.zip...
# time spent is 0.38010650078455605
# --------------------------------------------------------
# espnetv2_w3d2
# Downloading /root/.torch/models/espnetv2_w3d2-1129-3bbb49ad.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.238/espnetv2_w3d2-1129-3bbb49ad.pth.zip...
# time spent is 0.3996250112851461
# --------------------------------------------------------
# espnetv2_w2
# Downloading /root/.torch/models/espnetv2_w2-0961-13ba0f72.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.238/espnetv2_w2-0961-13ba0f72.pth.zip...
# time spent is 0.49729090531667075
# --------------------------------------------------------
# hrnet_w18_small_v1
# Downloading /root/.torch/models/hrnet_w18_small_v1-0933-77541fc6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnet_w18_small_v1-0933-77541fc6.pth.zip...
# download failed, retrying, 4 attempts left
# Downloading /root/.torch/models/hrnet_w18_small_v1-0933-77541fc6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnet_w18_small_v1-0933-77541fc6.pth.zip...
# time spent is 2.0762482404708864
# --------------------------------------------------------
# hrnet_w18_small_v2
# Downloading /root/.torch/models/hrnet_w18_small_v2-0758-27f85f31.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnet_w18_small_v2-0758-27f85f31.pth.zip...
# time spent is 3.3667112588882446
# --------------------------------------------------------
# hrnetv2_w18
# Downloading /root/.torch/models/hrnetv2_w18-0656-78b1f85b.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnetv2_w18-0656-78b1f85b.pth.zip...
# time spent is 7.026171255111694
# --------------------------------------------------------
# hrnetv2_w30
# Downloading /root/.torch/models/hrnetv2_w30-0578-839e57eb.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnetv2_w30-0578-839e57eb.pth.zip...
# time spent is 12.278431975841523
# --------------------------------------------------------
# hrnetv2_w32
# Downloading /root/.torch/models/hrnetv2_w32-0581-bef9ada0.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnetv2_w32-0581-bef9ada0.pth.zip...
# time spent is 12.919289807478586
# --------------------------------------------------------
# hrnetv2_w40
# Downloading /root/.torch/models/hrnetv2_w40-0553-e4b5a38a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnetv2_w40-0553-e4b5a38a.pth.zip...
# time spent is 15.398235686620076
# --------------------------------------------------------
# hrnetv2_w44
# Downloading /root/.torch/models/hrnetv2_w44-0563-9321bfd8.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnetv2_w44-0563-9321bfd8.pth.zip...
# time spent is 16.753573215007783
# --------------------------------------------------------
# hrnetv2_w48
# Downloading /root/.torch/models/hrnetv2_w48-0548-40f98610.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnetv2_w48-0548-40f98610.pth.zip...
# time spent is 18.130716665585837
# --------------------------------------------------------
# hrnetv2_w64
# Downloading /root/.torch/models/hrnetv2_w64-0535-5961efd0.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.421/hrnetv2_w64-0535-5961efd0.pth.zip...
# time spent is 28.019733238220216
# --------------------------------------------------------
# vovnet39
# Downloading /root/.torch/models/vovnet39-0657-27d24ae3.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.431/vovnet39-0657-27d24ae3.pth.zip...
# time spent is 3.6019172350565594
# --------------------------------------------------------
# vovnet57
# Downloading /root/.torch/models/vovnet57-0628-99f8a0c8.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.431/vovnet57-0628-99f8a0c8.pth.zip...
# time spent is 5.471252898375194
# --------------------------------------------------------
# selecsls42b
# Downloading /root/.torch/models/selecsls42b-0659-69337278.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.430/selecsls42b-0659-69337278.pth.zip...
# time spent is 3.9064112345377606
# --------------------------------------------------------
# selecsls60
# Downloading /root/.torch/models/selecsls60-0612-5261403f.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.430/selecsls60-0612-5261403f.pth.zip...
# time spent is 4.294968819618225
# --------------------------------------------------------
# selecsls60b
# Downloading /root/.torch/models/selecsls60b-0584-470ace6b.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.430/selecsls60b-0584-470ace6b.pth.zip...
# time spent is 4.356495988368988
# --------------------------------------------------------
# hardnet39ds
# Downloading /root/.torch/models/hardnet39ds-0957-9479e9ad.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.435/hardnet39ds-0957-9479e9ad.pth.zip...
# time spent is 0.5071298042933147
# --------------------------------------------------------
# hardnet68ds
# Downloading /root/.torch/models/hardnet68ds-0813-7187522d.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.435/hardnet68ds-0813-7187522d.pth.zip...
# time spent is 0.6223973155021667
# --------------------------------------------------------
# hardnet68
# Downloading /root/.torch/models/hardnet68-0699-2e207f79.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.435/hardnet68-0699-2e207f79.pth.zip...
# time spent is 2.0606054186820986
# --------------------------------------------------------
# hardnet85
# Downloading /root/.torch/models/hardnet85-0611-ae85d8af.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.435/hardnet85-0611-ae85d8af.pth.zip...
# time spent is 3.85791316429774
# --------------------------------------------------------
# squeezenet_v1_0
# Downloading /root/.torch/models/squeezenet_v1_0-1766-afdbcf1a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.128/squeezenet_v1_0-1766-afdbcf1a.pth.zip...
# time spent is 0.2176350156466166
# --------------------------------------------------------
# squeezenet_v1_1
# Downloading /root/.torch/models/squeezenet_v1_1-1772-25b77bc3.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.88/squeezenet_v1_1-1772-25b77bc3.pth.zip...
# time spent is 0.20708177089691163
# --------------------------------------------------------
# squeezeresnet_v1_0
# Downloading /root/.torch/models/squeezeresnet_v1_0-1809-25bfc02e.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.178/squeezeresnet_v1_0-1809-25bfc02e.pth.zip...
# time spent is 0.21446258227030437
# --------------------------------------------------------
# squeezeresnet_v1_1
# Downloading /root/.torch/models/squeezeresnet_v1_1-1821-c27ed88f.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.70/squeezeresnet_v1_1-1821-c27ed88f.pth.zip...
# time spent is 0.20447514057159424
# --------------------------------------------------------
# sqnxt23_w1
# Downloading /root/.torch/models/sqnxt23_w1-1906-97b74e0c.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.171/sqnxt23_w1-1906-97b74e0c.pth.zip...
# time spent is 0.45873609781265257
# --------------------------------------------------------
# sqnxt23v5_w1
# Downloading /root/.torch/models/sqnxt23v5_w1-1785-2fe3ad67.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.172/sqnxt23v5_w1-1785-2fe3ad67.pth.zip...
# time spent is 0.5729009111722311
# --------------------------------------------------------
# sqnxt23_w3d2
# Downloading /root/.torch/models/sqnxt23_w3d2-1350-c2f21bce.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.210/sqnxt23_w3d2-1350-c2f21bce.pth.zip...
# time spent is 0.5421759605407714
# --------------------------------------------------------
# sqnxt23v5_w3d2
# Downloading /root/.torch/models/sqnxt23v5_w3d2-1301-c244844b.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.212/sqnxt23v5_w3d2-1301-c244844b.pth.zip...
# time spent is 0.6998462637265523
# --------------------------------------------------------
# sqnxt23_w2
# Downloading /root/.torch/models/sqnxt23_w2-1100-b9bb7302.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.240/sqnxt23_w2-1100-b9bb7302.pth.zip...
# time spent is 0.908391284942627
# --------------------------------------------------------
# sqnxt23v5_w2
# Downloading /root/.torch/models/sqnxt23v5_w2-1066-229b0d3d.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.216/sqnxt23v5_w2-1066-229b0d3d.pth.zip...
# time spent is 1.173534353574117
# --------------------------------------------------------
# shufflenet_g1_wd4
# Downloading /root/.torch/models/shufflenet_g1_wd4-3729-47dbd0f2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.134/shufflenet_g1_wd4-3729-47dbd0f2.pth.zip...
# time spent is 0.06927738189697266
# --------------------------------------------------------
# shufflenet_g3_wd4
# Downloading /root/.torch/models/shufflenet_g3_wd4-3653-6abdd65e.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.135/shufflenet_g3_wd4-3653-6abdd65e.pth.zip...
# time spent is 0.08520489533742269
# --------------------------------------------------------
# shufflenet_g1_wd2
# Downloading /root/.torch/models/shufflenet_g1_wd2-2261-dae4bdad.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.174/shufflenet_g1_wd2-2261-dae4bdad.pth.zip...
# time spent is 0.11525559822718302
# --------------------------------------------------------
# shufflenet_g3_wd2
# Downloading /root/.torch/models/shufflenet_g3_wd2-2080-ccaacfc8.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.167/shufflenet_g3_wd2-2080-ccaacfc8.pth.zip...
# time spent is 0.1477264205614726
# --------------------------------------------------------
# shufflenet_g1_w3d4
# Downloading /root/.torch/models/shufflenet_g1_w3d4-1711-161cd24a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.218/shufflenet_g1_w3d4-1711-161cd24a.pth.zip...
# time spent is 0.1997298757235209
# --------------------------------------------------------
# shufflenet_g3_w3d4
# Downloading /root/.torch/models/shufflenet_g3_w3d4-1650-3f3b0aef.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.219/shufflenet_g3_w3d4-1650-3f3b0aef.pth.zip...
# time spent is 0.22156542142232258
# --------------------------------------------------------
# shufflenet_g1_w1
# Downloading /root/.torch/models/shufflenet_g1_w1-1389-4cfb65a3.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.223/shufflenet_g1_w1-1389-4cfb65a3.pth.zip...
# time spent is 0.24967645009358724
# --------------------------------------------------------
# shufflenet_g2_w1
# Downloading /root/.torch/models/shufflenet_g2_w1-1363-07256203.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.241/shufflenet_g2_w1-1363-07256203.pth.zip...
# time spent is 0.2935389002164205
# --------------------------------------------------------
# shufflenet_g3_w1
# Downloading /root/.torch/models/shufflenet_g3_w1-1348-ce54f64e.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.244/shufflenet_g3_w1-1348-ce54f64e.pth.zip...
# time spent is 0.3028732697168986
# --------------------------------------------------------
# shufflenet_g4_w1
# Downloading /root/.torch/models/shufflenet_g4_w1-1335-e2415f82.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.245/shufflenet_g4_w1-1335-e2415f82.pth.zip...
# time spent is 0.3247504154841105
# --------------------------------------------------------
# shufflenet_g8_w1
# Downloading /root/.torch/models/shufflenet_g8_w1-1342-9a979b36.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.250/shufflenet_g8_w1-1342-9a979b36.pth.zip...
# time spent is 0.264388640721639
# --------------------------------------------------------
# shufflenetv2_wd2
# Downloading /root/.torch/models/shufflenetv2_wd2-1865-9c22238b.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.90/shufflenetv2_wd2-1865-9c22238b.pth.zip...
# time spent is 0.2419183850288391
# --------------------------------------------------------
# shufflenetv2_w1
# Downloading /root/.torch/models/shufflenetv2_w1-1163-c71dfb7a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.133/shufflenetv2_w1-1163-c71dfb7a.pth.zip...
# time spent is 0.4644698659578959
# --------------------------------------------------------
# shufflenetv2_w3d2
# Downloading /root/.torch/models/shufflenetv2_w3d2-0942-26a92304.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.288/shufflenetv2_w3d2-0942-26a92304.pth.zip...
# time spent is 0.6593104283014933
# --------------------------------------------------------
# shufflenetv2_w2
# Downloading /root/.torch/models/shufflenetv2_w2-0845-337255f6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.301/shufflenetv2_w2-0845-337255f6.pth.zip...
# time spent is 0.9404927810033162
# --------------------------------------------------------
# shufflenetv2b_wd2
# Downloading /root/.torch/models/shufflenetv2b_wd2-1822-01d18d6f.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.157/shufflenetv2b_wd2-1822-01d18d6f.pth.zip...
# time spent is 0.2559017817179362
# --------------------------------------------------------
# shufflenetv2b_w1
# Downloading /root/.torch/models/shufflenetv2b_w1-1125-6a5d3dc4.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.161/shufflenetv2b_w1-1125-6a5d3dc4.pth.zip...
# time spent is 0.48376331726710003
# --------------------------------------------------------
# shufflenetv2b_w3d2
# Downloading /root/.torch/models/shufflenetv2b_w3d2-0911-f2106fee.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.203/shufflenetv2b_w3d2-0911-f2106fee.pth.zip...
# time spent is 0.6762977719306946
# --------------------------------------------------------
# shufflenetv2b_w2
# Downloading /root/.torch/models/shufflenetv2b_w2-0834-cb36b92c.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.242/shufflenetv2b_w2-0834-cb36b92c.pth.zip...
# time spent is 0.9544425964355469
# --------------------------------------------------------
# menet108_8x1_g3
# Downloading /root/.torch/models/menet108_8x1_g3-2076-6acc82e4.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.89/menet108_8x1_g3-2076-6acc82e4.pth.zip...
# time spent is 0.21785421371459962
# --------------------------------------------------------
# menet128_8x1_g4
# Downloading /root/.torch/models/menet128_8x1_g4-1959-48fa80fc.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.103/menet128_8x1_g4-1959-48fa80fc.pth.zip...
# time spent is 0.23156452178955078
# --------------------------------------------------------
# menet160_8x1_g8
# Downloading /root/.torch/models/menet160_8x1_g8-2084-0f4fce43.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.154/menet160_8x1_g8-2084-0f4fce43.pth.zip...
# time spent is 0.21334952513376873
# --------------------------------------------------------
# menet228_12x1_g3
# Downloading /root/.torch/models/menet228_12x1_g3-1316-5b670c42.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.131/menet228_12x1_g3-1316-5b670c42.pth.zip...
# time spent is 0.36243427197138467
# --------------------------------------------------------
# menet256_12x1_g4
# Downloading /root/.torch/models/menet256_12x1_g4-1252-14c6c86d.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.152/menet256_12x1_g4-1252-14c6c86d.pth.zip...
# time spent is 0.3999455412228902
# --------------------------------------------------------
# menet348_12x1_g3
# Downloading /root/.torch/models/menet348_12x1_g3-0958-ad50f635.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.173/menet348_12x1_g3-0958-ad50f635.pth.zip...
# time spent is 0.5026602268218994
# --------------------------------------------------------
# menet352_12x1_g8
# Downloading /root/.torch/models/menet352_12x1_g8-1200-4ee200c5.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.198/menet352_12x1_g8-1200-4ee200c5.pth.zip...
# time spent is 0.3368683338165283
# --------------------------------------------------------
# menet456_24x1_g3
# Downloading /root/.torch/models/menet456_24x1_g3-0799-826c0022.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.237/menet456_24x1_g3-0799-826c0022.pth.zip...
# time spent is 0.6044718345006307
# --------------------------------------------------------
# mobilenet_wd4
# Downloading /root/.torch/models/mobilenet_wd4-2249-1ad5e8fe.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.62/mobilenet_wd4-2249-1ad5e8fe.pth.zip...
# time spent is 0.1224312702814738
# --------------------------------------------------------
# mobilenet_wd2
# Downloading /root/.torch/models/mobilenet_wd2-1355-41a21242.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.156/mobilenet_wd2-1355-41a21242.pth.zip...
# time spent is 0.2604817390441895
# --------------------------------------------------------
# mobilenet_w3d4
# Downloading /root/.torch/models/mobilenet_w3d4-1076-d801bcae.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.130/mobilenet_w3d4-1076-d801bcae.pth.zip...
# time spent is 0.3721415003140767
# --------------------------------------------------------
# mobilenet_w1
# Downloading /root/.torch/models/mobilenet_w1-0895-7e1d739f.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.155/mobilenet_w1-0895-7e1d739f.pth.zip...
# time spent is 0.5641550103823344
# --------------------------------------------------------
# fdmobilenet_wd4
# Downloading /root/.torch/models/fdmobilenet_wd4-3098-2b22b709.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.177/fdmobilenet_wd4-3098-2b22b709.pth.zip...
# time spent is 0.09906750917434692
# --------------------------------------------------------
# fdmobilenet_wd2
# Downloading /root/.torch/models/fdmobilenet_wd2-2015-414dbeed.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.83/fdmobilenet_wd2-2015-414dbeed.pth.zip...
# time spent is 0.17347062826156617
# --------------------------------------------------------
# fdmobilenet_w3d4
# Downloading /root/.torch/models/fdmobilenet_w3d4-1641-5561d58a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.159/fdmobilenet_w3d4-1641-5561d58a.pth.zip...
# time spent is 0.26897670030593873
# --------------------------------------------------------
# fdmobilenet_w1
# Downloading /root/.torch/models/fdmobilenet_w1-1338-9d026c04.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.162/fdmobilenet_w1-1338-9d026c04.pth.zip...
# time spent is 0.39334555466969806
# --------------------------------------------------------
# mobilenetv2_wd4
# Downloading /root/.torch/models/mobilenetv2_wd4-2451-05e1e3a2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.137/mobilenetv2_wd4-2451-05e1e3a2.pth.zip...
# time spent is 0.21144471565882364
# --------------------------------------------------------
# mobilenetv2_wd2
# Downloading /root/.torch/models/mobilenetv2_wd2-1493-b82d79f6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.170/mobilenetv2_wd2-1493-b82d79f6.pth.zip...
# time spent is 0.2504634420077006
# --------------------------------------------------------
# mobilenetv2_w3d4
# Downloading /root/.torch/models/mobilenetv2_w3d4-1082-8656de5a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.230/mobilenetv2_w3d4-1082-8656de5a.pth.zip...
# time spent is 0.3055288036664327
# --------------------------------------------------------
# mobilenetv2_w1
# Downloading /root/.torch/models/mobilenetv2_w1-0887-13a021bc.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.213/mobilenetv2_w1-0887-13a021bc.pth.zip...
# time spent is 0.37571938037872316
# --------------------------------------------------------
# mobilenetv3_large_w1
# Downloading /root/.torch/models/mobilenetv3_large_w1-0779-38e392f5.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.411/mobilenetv3_large_w1-0779-38e392f5.pth.zip...
# time spent is 0.568840209643046
# --------------------------------------------------------
# igcv3_wd4
# Downloading /root/.torch/models/igcv3_wd4-2871-c9f28301.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.142/igcv3_wd4-2871-c9f28301.pth.zip...
# time spent is 0.2684826294581095
# --------------------------------------------------------
# igcv3_wd2
# Downloading /root/.torch/models/igcv3_wd2-1732-8c504f44.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.132/igcv3_wd2-1732-8c504f44.pth.zip...
# time spent is 0.30353184541066486
# --------------------------------------------------------
# igcv3_w3d4
# Downloading /root/.torch/models/igcv3_w3d4-1140-63f43cf8.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.207/igcv3_w3d4-1140-63f43cf8.pth.zip...
# time spent is 0.3826020081837972
# --------------------------------------------------------
# igcv3_w1
# Downloading /root/.torch/models/igcv3_w1-0920-12385791.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.243/igcv3_w1-0920-12385791.pth.zip...
# time spent is 0.45809983015060424
# --------------------------------------------------------
# mnasnet_b1
# Downloading /root/.torch/models/mnasnet_b1-0785-188ea3e9.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.419/mnasnet_b1-0785-188ea3e9.pth.zip...
# time spent is 0.41136875152587893
# --------------------------------------------------------
# mnasnet_a1
# Downloading /root/.torch/models/mnasnet_a1-0744-e415e240.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.419/mnasnet_a1-0744-e415e240.pth.zip...
# time spent is 0.40219794114430746
# --------------------------------------------------------
# darts
# Downloading /root/.torch/models/darts-0874-74f0c7b6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.118/darts-0874-74f0c7b6.pth.zip...
# time spent is 1.3078285336494446
# --------------------------------------------------------
# proxylessnas_cpu
# Downloading /root/.torch/models/proxylessnas_cpu-0761-fe9572b1.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.304/proxylessnas_cpu-0761-fe9572b1.pth.zip...
# time spent is 0.44404673178990683
# --------------------------------------------------------
# proxylessnas_gpu
# Downloading /root/.torch/models/proxylessnas_gpu-0745-acca5941.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.333/proxylessnas_gpu-0745-acca5941.pth.zip...
# time spent is 0.5047186891237895
# --------------------------------------------------------
# proxylessnas_mobile
# Downloading /root/.torch/models/proxylessnas_mobile-0780-639a90c2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.304/proxylessnas_mobile-0780-639a90c2.pth.zip...
# time spent is 0.4428688049316406
# --------------------------------------------------------
# proxylessnas_mobile14
# Downloading /root/.torch/models/proxylessnas_mobile14-0662-0c0ad983.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.331/proxylessnas_mobile14-0662-0c0ad983.pth.zip...
# time spent is 0.5897136727968851
# --------------------------------------------------------
# fbnet_cb
# Downloading /root/.torch/models/fbnet_cb-0762-2edb61f8.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.415/fbnet_cb-0762-2edb61f8.pth.zip...
# time spent is 0.49065170288085935
# --------------------------------------------------------
# xception
# Downloading /root/.torch/models/xception-0549-e4f0232c.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.115/xception-0549-e4f0232c.pth.zip...
# time spent is 2.5383448282877605
# --------------------------------------------------------
# inceptionv3
# Downloading /root/.torch/models/inceptionv3-0565-cf406180.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.92/inceptionv3-0565-cf406180.pth.zip...
# time spent is 4.160104091962179
# --------------------------------------------------------
# inceptionv4
# Downloading /root/.torch/models/inceptionv4-0529-5cb7b4e4.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.105/inceptionv4-0529-5cb7b4e4.pth.zip...
# time spent is 7.111035521825155
# --------------------------------------------------------
# inceptionresnetv2
# Downloading /root/.torch/models/inceptionresnetv2-0490-1d1b4d18.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.107/inceptionresnetv2-0490-1d1b4d18.pth.zip...
# time spent is 6.665687636534373
# --------------------------------------------------------
# polynet
# Downloading /root/.torch/models/polynet-0452-6a1b295d.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.96/polynet-0452-6a1b295d.pth.zip...
# time spent is 11.20097666978836
# --------------------------------------------------------
# nasnet_4a1056
# Downloading /root/.torch/models/nasnet_4a1056-0816-d21bbaf5.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.97/nasnet_4a1056-0816-d21bbaf5.pth.zip...
# time spent is 1.4321490248044333
# --------------------------------------------------------
# nasnet_6a4032
# Downloading /root/.torch/models/nasnet_6a4032-0421-f354d28f.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.101/nasnet_6a4032-0421-f354d28f.pth.zip...
# time spent is 8.484790567557017
# --------------------------------------------------------
# pnasnet5large
# Downloading /root/.torch/models/pnasnet5large-0428-65de46eb.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.114/pnasnet5large-0428-65de46eb.pth.zip...
# time spent is 8.576031986872355
# --------------------------------------------------------
# spnasnet
# Downloading /root/.torch/models/spnasnet-0817-290a4fd9.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.416/spnasnet-0817-290a4fd9.pth.zip...
# time spent is 0.4555071194966634
# --------------------------------------------------------
# efficientnet_b0
# Downloading /root/.torch/models/efficientnet_b0-0752-0e386130.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.364/efficientnet_b0-0752-0e386130.pth.zip...
# time spent is 0.47949714263280235
# --------------------------------------------------------
# efficientnet_b1
# Downloading /root/.torch/models/efficientnet_b1-0638-ac77bcd7.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.376/efficientnet_b1-0638-ac77bcd7.pth.zip...
# time spent is 0.5978361050287883
# --------------------------------------------------------
# efficientnet_b0b
# Downloading /root/.torch/models/efficientnet_b0b-0702-ecf61b9b.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.403/efficientnet_b0b-0702-ecf61b9b.pth.zip...
# time spent is 0.4578202406565348
# --------------------------------------------------------
# efficientnet_b1b
# Downloading /root/.torch/models/efficientnet_b1b-0594-614e8166.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.403/efficientnet_b1b-0594-614e8166.pth.zip...
# time spent is 0.6170860370000203
# --------------------------------------------------------
# efficientnet_b2b
# Downloading /root/.torch/models/efficientnet_b2b-0527-531f10e6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.403/efficientnet_b2b-0527-531f10e6.pth.zip...
# time spent is 0.6973531603813171
# --------------------------------------------------------
# efficientnet_b3b
# Downloading /root/.torch/models/efficientnet_b3b-0445-3c5fbba8.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.403/efficientnet_b3b-0445-3c5fbba8.pth.zip...
# time spent is 0.8366642236709595
# --------------------------------------------------------
# efficientnet_b4b
# Downloading /root/.torch/models/efficientnet_b4b-0389-6305bfe6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.403/efficientnet_b4b-0389-6305bfe6.pth.zip...
# time spent is 1.148307490348816
# --------------------------------------------------------
# efficientnet_b5b
# Downloading /root/.torch/models/efficientnet_b5b-0337-e1c2ffcf.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.403/efficientnet_b5b-0337-e1c2ffcf.pth.zip...
# time spent is 1.5500842849413554
# --------------------------------------------------------
# efficientnet_b6b
# Downloading /root/.torch/models/efficientnet_b6b-0323-e5c1d7c3.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.403/efficientnet_b6b-0323-e5c1d7c3.pth.zip...
# time spent is 2.022736903031667
# --------------------------------------------------------
# efficientnet_b7b
# Downloading /root/.torch/models/efficientnet_b7b-0322-b9c5965a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.403/efficientnet_b7b-0322-b9c5965a.pth.zip...
# time spent is 2.8476778348286946
# --------------------------------------------------------
# efficientnet_b0c
# Downloading /root/.torch/models/efficientnet_b0c-0675-21778c6e.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.433/efficientnet_b0c-0675-21778c6e.pth.zip...
# time spent is 0.4580891847610474
# --------------------------------------------------------
# efficientnet_b1c
# Downloading /root/.torch/models/efficientnet_b1c-0569-239ed6a4.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.433/efficientnet_b1c-0569-239ed6a4.pth.zip...
# time spent is 0.6062315742174784
# --------------------------------------------------------
# efficientnet_b2c
# Downloading /root/.torch/models/efficientnet_b2c-0503-be48d3d7.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.433/efficientnet_b2c-0503-be48d3d7.pth.zip...
# time spent is 0.6852427840232849
# --------------------------------------------------------
# efficientnet_b3c
# Downloading /root/.torch/models/efficientnet_b3c-0442-ea7080ab.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.433/efficientnet_b3c-0442-ea7080ab.pth.zip...
# time spent is 0.8316040436426798
# --------------------------------------------------------
# efficientnet_b4c
# Downloading /root/.torch/models/efficientnet_b4c-0369-5954cc05.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.433/efficientnet_b4c-0369-5954cc05.pth.zip...
# time spent is 1.1584400574366251
# --------------------------------------------------------
# efficientnet_b5c
# Downloading /root/.torch/models/efficientnet_b5c-0310-589fefc6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.433/efficientnet_b5c-0310-589fefc6.pth.zip...
# time spent is 1.571187190214793
# --------------------------------------------------------
# efficientnet_b6c
# Downloading /root/.torch/models/efficientnet_b6c-0296-546e61da.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.433/efficientnet_b6c-0296-546e61da.pth.zip...
# time spent is 2.0517568945884705
# --------------------------------------------------------
# efficientnet_b7c
# Downloading /root/.torch/models/efficientnet_b7c-0288-13d683f2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.433/efficientnet_b7c-0288-13d683f2.pth.zip...
# time spent is 2.8583876689275107
# --------------------------------------------------------
# efficientnet_b8c
# Downloading /root/.torch/models/efficientnet_b8c-0276-a9973d66.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.433/efficientnet_b8c-0276-a9973d66.pth.zip...
# time spent is 3.5928825815518697
# --------------------------------------------------------
# efficientnet_edge_small_b
# Downloading /root/.torch/models/efficientnet_edge_small_b-0640-e27c3444.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.434/efficientnet_edge_small_b-0640-e27c3444.pth.zip...
# time spent is 0.41256159941355386
# --------------------------------------------------------
# efficientnet_edge_medium_b
# Downloading /root/.torch/models/efficientnet_edge_medium_b-0563-99fa34c7.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.434/efficientnet_edge_medium_b-0563-99fa34c7.pth.zip...
# time spent is 0.5022920211156209
# --------------------------------------------------------
# efficientnet_edge_large_b
# Downloading /root/.torch/models/efficientnet_edge_large_b-0491-d502326f.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.434/efficientnet_edge_large_b-0491-d502326f.pth.zip...
# time spent is 0.8623845299084981
# --------------------------------------------------------
# mixnet_s
# Downloading /root/.torch/models/mixnet_s-0719-aeafe843.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.412/mixnet_s-0719-aeafe843.pth.zip...
# time spent is 0.45481191476186117
# --------------------------------------------------------
# mixnet_m
# Downloading /root/.torch/models/mixnet_m-0660-5aab9fbd.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.413/mixnet_m-0660-5aab9fbd.pth.zip...
# time spent is 0.5406368652979533
# --------------------------------------------------------
# mixnet_l
# Downloading /root/.torch/models/mixnet_l-0582-6cf2c975.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.414/mixnet_l-0582-6cf2c975.pth.zip...
# time spent is 0.7618412176767985
# --------------------------------------------------------
# resnetd50b
# Downloading /root/.torch/models/resnetd50b-0565-ec03d815.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.296/resnetd50b-0565-ec03d815.pth.zip...
# time spent is 3.257347587744395
# --------------------------------------------------------
# resnetd101b
# Downloading /root/.torch/models/resnetd101b-0473-f851c920.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.296/resnetd101b-0473-f851c920.pth.zip...
# time spent is 6.1865208069483435
# --------------------------------------------------------
# resnetd152b
# Downloading /root/.torch/models/resnetd152b-0482-112e216d.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.296/resnetd152b-0482-112e216d.pth.zip...
# time spent is 8.784857483704885
# --------------------------------------------------------
# nin_cifar10
# Downloading /root/.torch/models/nin_cifar10-0743-795b0824.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.175/nin_cifar10-0743-795b0824.pth.zip...
# time spent is 0.28668580849965414
# --------------------------------------------------------
# nin_cifar100
# Downloading /root/.torch/models/nin_cifar100-2839-627a11c0.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.183/nin_cifar100-2839-627a11c0.pth.zip...
# time spent is 0.30876155296961466
# --------------------------------------------------------
# nin_svhn
# Downloading /root/.torch/models/nin_svhn-0376-1205dc06.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.270/nin_svhn-0376-1205dc06.pth.zip...
# time spent is 0.28637746572494505
# --------------------------------------------------------
# resnet20_cifar10
# Downloading /root/.torch/models/resnet20_cifar10-0597-9b0024ac.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet20_cifar10-0597-9b0024ac.pth.zip...
# time spent is 0.26081018447875975
# --------------------------------------------------------
# resnet20_cifar100
# Downloading /root/.torch/models/resnet20_cifar100-2964-a5322afe.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.180/resnet20_cifar100-2964-a5322afe.pth.zip...
# time spent is 0.2649113853772481
# --------------------------------------------------------
# resnet20_svhn
# Downloading /root/.torch/models/resnet20_svhn-0343-8232e6e4.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.265/resnet20_svhn-0343-8232e6e4.pth.zip...
# time spent is 0.26209117968877155
# --------------------------------------------------------
# resnet56_cifar10
# Downloading /root/.torch/models/resnet56_cifar10-0452-628c42a2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet56_cifar10-0452-628c42a2.pth.zip...
# time spent is 0.8568838636080424
# --------------------------------------------------------
# resnet56_cifar100
# Downloading /root/.torch/models/resnet56_cifar100-2488-d65f53b1.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.181/resnet56_cifar100-2488-d65f53b1.pth.zip...
# time spent is 0.8485408226648966
# --------------------------------------------------------
# resnet56_svhn
# Downloading /root/.torch/models/resnet56_svhn-0275-6e08ed92.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.265/resnet56_svhn-0275-6e08ed92.pth.zip...
# time spent is 0.8481805483500163
# --------------------------------------------------------
# resnet110_cifar10
# Downloading /root/.torch/models/resnet110_cifar10-0369-4d6ca1fc.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet110_cifar10-0369-4d6ca1fc.pth.zip...
# time spent is 1.7678181131680806
# --------------------------------------------------------
# resnet110_cifar100
# Downloading /root/.torch/models/resnet110_cifar100-2280-d8d397a7.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.190/resnet110_cifar100-2280-d8d397a7.pth.zip...
# time spent is 1.7584429502487182
# --------------------------------------------------------
# resnet110_svhn
# Downloading /root/.torch/models/resnet110_svhn-0245-c971f0a3.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.265/resnet110_svhn-0245-c971f0a3.pth.zip...
# time spent is 1.770389688014984
# --------------------------------------------------------
# resnet164bn_cifar10
# Downloading /root/.torch/models/resnet164bn_cifar10-0368-74ae9f4b.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.179/resnet164bn_cifar10-0368-74ae9f4b.pth.zip...
# time spent is 1.2407870610555014
# --------------------------------------------------------
# resnet164bn_cifar100
# Downloading /root/.torch/models/resnet164bn_cifar100-2044-8fa07b72.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.182/resnet164bn_cifar100-2044-8fa07b72.pth.zip...
# time spent is 1.2532032052675883
# --------------------------------------------------------
# resnet164bn_svhn
# Downloading /root/.torch/models/resnet164bn_svhn-0242-54941372.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.267/resnet164bn_svhn-0242-54941372.pth.zip...
# time spent is 1.2524084329605103
# --------------------------------------------------------
# resnet272bn_cifar10
# Downloading /root/.torch/models/resnet272bn_cifar10-0333-84f28e0c.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.368/resnet272bn_cifar10-0333-84f28e0c.pth.zip...
# time spent is 2.1922850688298543
# --------------------------------------------------------
# resnet272bn_cifar100
# Downloading /root/.torch/models/resnet272bn_cifar100-2007-a80d2b3c.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.368/resnet272bn_cifar100-2007-a80d2b3c.pth.zip...
# time spent is 2.1233776370684305
# --------------------------------------------------------
# resnet272bn_svhn
# Downloading /root/.torch/models/resnet272bn_svhn-0243-ab1d7da5.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.368/resnet272bn_svhn-0243-ab1d7da5.pth.zip...
# time spent is 2.1243030031522117
# --------------------------------------------------------
# resnet542bn_cifar10
# Downloading /root/.torch/models/resnet542bn_cifar10-0343-0fd36dd1.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.369/resnet542bn_cifar10-0343-0fd36dd1.pth.zip...
# time spent is 4.65252643028895
# --------------------------------------------------------
# resnet542bn_cifar100
# Downloading /root/.torch/models/resnet542bn_cifar100-1932-a631d3ce.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.369/resnet542bn_cifar100-1932-a631d3ce.pth.zip...
# time spent is 4.853066436449686
# --------------------------------------------------------
# resnet542bn_svhn
# Downloading /root/.torch/models/resnet542bn_svhn-0234-04396c97.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.369/resnet542bn_svhn-0234-04396c97.pth.zip...
# time spent is 4.619321497281392
# --------------------------------------------------------
# resnet1001_cifar10
# Downloading /root/.torch/models/resnet1001_cifar10-0328-77a179e2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.201/resnet1001_cifar10-0328-77a179e2.pth.zip...
# time spent is 9.754861338933308
# --------------------------------------------------------
# resnet1001_cifar100
# Downloading /root/.torch/models/resnet1001_cifar100-1979-2728b558.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.254/resnet1001_cifar100-1979-2728b558.pth.zip...
# time spent is 9.67395987113317
# --------------------------------------------------------
# resnet1001_svhn
# Downloading /root/.torch/models/resnet1001_svhn-0241-9e3d4bb5.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.408/resnet1001_svhn-0241-9e3d4bb5.pth.zip...
# time spent is 9.668955790996552
# --------------------------------------------------------
# resnet1202_cifar10
# Downloading /root/.torch/models/resnet1202_cifar10-0353-1d5a2129.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.214/resnet1202_cifar10-0353-1d5a2129.pth.zip...
# time spent is 32.52223325967789
# --------------------------------------------------------
# resnet1202_cifar100
# Downloading /root/.torch/models/resnet1202_cifar100-2156-86ecd091.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.410/resnet1202_cifar100-2156-86ecd091.pth.zip...
# time spent is 32.36509522596995
# --------------------------------------------------------
# preresnet20_cifar10
# Downloading /root/.torch/models/preresnet20_cifar10-0651-76cec68d.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.164/preresnet20_cifar10-0651-76cec68d.pth.zip...
# time spent is 0.2537346084912618
# --------------------------------------------------------
# preresnet20_cifar100
# Downloading /root/.torch/models/preresnet20_cifar100-3022-3dbfa6a2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.187/preresnet20_cifar100-3022-3dbfa6a2.pth.zip...
# time spent is 0.25997347036997476
# --------------------------------------------------------
# preresnet20_svhn
# Downloading /root/.torch/models/preresnet20_svhn-0322-c3c00fed.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.269/preresnet20_svhn-0322-c3c00fed.pth.zip...
# time spent is 0.2535679419835409
# --------------------------------------------------------
# preresnet56_cifar10
# Downloading /root/.torch/models/preresnet56_cifar10-0449-e9124fcf.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.164/preresnet56_cifar10-0449-e9124fcf.pth.zip...
# time spent is 0.843327271938324
# --------------------------------------------------------
# preresnet56_cifar100
# Downloading /root/.torch/models/preresnet56_cifar100-2505-ca90a2be.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.188/preresnet56_cifar100-2505-ca90a2be.pth.zip...
# time spent is 0.8448640982309977
# --------------------------------------------------------
# preresnet56_svhn
# Downloading /root/.torch/models/preresnet56_svhn-0280-b51b4147.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.269/preresnet56_svhn-0280-b51b4147.pth.zip...
# time spent is 0.8476992646853129
# --------------------------------------------------------
# preresnet110_cifar10
# Downloading /root/.torch/models/preresnet110_cifar10-0386-cc08946a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.164/preresnet110_cifar10-0386-cc08946a.pth.zip...
# time spent is 1.769357426961263
# --------------------------------------------------------
# preresnet110_cifar100
# Downloading /root/.torch/models/preresnet110_cifar100-2267-3954e915.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.191/preresnet110_cifar100-2267-3954e915.pth.zip...
# time spent is 1.7656054019927978
# --------------------------------------------------------
# preresnet110_svhn
# Downloading /root/.torch/models/preresnet110_svhn-0279-aa49e0a3.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.269/preresnet110_svhn-0279-aa49e0a3.pth.zip...
# time spent is 1.7755830446879068
# --------------------------------------------------------
# preresnet164bn_cifar10
# Downloading /root/.torch/models/preresnet164bn_cifar10-0364-429012d4.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.196/preresnet164bn_cifar10-0364-429012d4.pth.zip...
# time spent is 1.246337346235911
# --------------------------------------------------------
# preresnet164bn_cifar100
# Downloading /root/.torch/models/preresnet164bn_cifar100-2018-a8e67ca6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.192/preresnet164bn_cifar100-2018-a8e67ca6.pth.zip...
# time spent is 1.2429843505223592
# --------------------------------------------------------
# preresnet164bn_svhn
# Downloading /root/.torch/models/preresnet164bn_svhn-0258-94d42de4.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.269/preresnet164bn_svhn-0258-94d42de4.pth.zip...
# time spent is 1.2414826552073162
# --------------------------------------------------------
# preresnet272bn_cifar10
# Downloading /root/.torch/models/preresnet272bn_cifar10-0325-1a6a016e.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.389/preresnet272bn_cifar10-0325-1a6a016e.pth.zip...
# time spent is 2.1315285483996074
# --------------------------------------------------------

# %% [markdown]
# # Stop Here until all data is available

# %%
## Export the whole dataset mannually
# ddf = pd.DataFrame.from_dict(data).transpose()
# ddf.to_excel(path + '/df_all.xlsx')
#files.download(path + '/df_all.xlsx')
# ddf.to_excel(path + '/data_{}-{}_{}.xlsx'.format(start, i, dt.date.today()))

# %%
if notfound != []:
    pd.DataFrame(notfound).to_excel(path + '/notfound_{}.xlsx'.format(dt.date.today()))
    print('There are models not found')

if ww_error != []:
    pd.DataFrame(notfound).to_excel(path + '/ww_error_{}.xlsx'.format(dt.date.today()))
    print('There are models not analyzed successfully')

# %% [markdown]
# # Read in all pre-computed Data

# %%
try:
    ## Load the model results data
    # df_all = pd.read_excel('/content/drive/My Drive/df_all.xlsx')\
    #       .rename(columns = {'Unnamed: 0': 'index'}).set_index('index')
    df_all = pd.read_excel(path + '/df_all.xlsx', index_col = 0)
    # print(df_all)
except:
    ## If the above cell runs different batches of the data
    ## Use this cell to concat the data together
    print('Concating files...')
    df_all = pd.DataFrame()
    for f in os.listdir(path):
        if f.startswith('data_'): #detect data
            tempp = pd.read_excel(path + '/' + f)\
                        .rename(columns = {'Unnamed: 0':'modelname'})
            df_all = pd.concat([df_all, tempp], axis = 0, sort = False)
            print(f)
            print(df_all.tail(1))

    del tempp

    df_all = df_all.drop_duplicates().reset_index(drop = True)
    df_all.to_excel(path + '/df_all.xlsx')

#rint(len(df_all))
#df_all.dropna(inplace=True)
#print(len(df_all))

# %%
df_all

# %%
## Get the modelname of outliers
# temp = df_all.copy()
# temp = temp.sort_values(['softrank'], ascending = False)
# outliers_sr = temp['modelname'].tolist()[:10]

# temp = temp.sort_values(['spectralnorm'], ascending = False)
# outliers_sp = temp['modelname'].tolist()[:10]

# [s for s in outliers_sp if s not in outliers_sr]

# %%
## Get the details of outliers
# writer = pd.ExcelWriter('/content/drive/My Drive/sp_outliers.xlsx')
# for s in [s for s in outliers_sp if s not in outliers_sr]:#outliers:
#     model = ptcv_get_model(s, pretrained=True) #'resnet542bn_svhn'
#     watcher = ww.WeightWatcher(model=model, logger=logger)
#     results = watcher.analyze(compute_alphas = False, compute_spectralnorms=True, compute_softranks=True)
    
#     temp1 = watcher.get_details()
#     temp1.to_excel(writer, s)
    
# writer.save()

# %% [markdown]
# ### **2. Plots with Test Accuracies**

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
'''Load the test accuracies'''
url = "https://github.com/osmr/imgclsmob/blob/master/pytorch/README.md"
df_accuracy = pd.read_html(url)

# %%
'''Create the matchtable: Match the model name'''
response = requests.get(url)
page = str(BeautifulSoup(response.content, features="lxml"))

## To find the category of models to group when plotting
models = re.findall('<li>(.*) \(<a href=', page) 

## The naming convention is not very consistent, therefore, to help with identification,
## I input the exceptions
exceptions = {'SqueezeNext': 'SqNxt', 'DIA-ResNet': 'DIA-PreResNet', 
              'DarkNet Ref/Tiny/19': 'DarkNet Tiny', 
              'IBN-ResNet/IBN-ResNeXt/IBN-DenseNet': 'IBN(b)-ResNet'} 
models_ = [m if m not in exceptions.keys() else m+'/'+exceptions[m] for m in models]
models_ = [m.split('/') for m in models_]

## Use reg exp to extract the dataset name, modelnames (used in README), and 
## modelnames (used in codes)
datasets = re.findall('<h3><a aria-hidden="true" class="anchor" href="#(.*)" id', page)
lst1_name = re.findall('<tr>\n<td>(.*)</td>', page)
lst2_name = re.findall('\n<td>.* \(<a href="(.*)">log</a>\)</td>\n</tr>', page)

if len(lst1_name) != len(lst2_name):
    print('Number does not match!')

df_table = pd.DataFrame(lst1_name, columns = ['Model'])

## Note: there are duplicate Model names, hence cannot use merge naively
df_table['modelname'] = [m.split('/')[-1][:-22] for m in lst2_name]

# %%
'''Identify the architexture for each pretrained model'''
class ContinueI(Exception):
    pass

continue_i = ContinueI()

arch = []
for i in range(len(df_table)):
    try:
        for mm in models_:
            for m1 in mm:
                ## Name convention 1: the model name starts with the arch name
                if df_table.loc[i, 'Model'].startswith(m1): 
                    arch.append(mm)
                    raise continue_i
        try:
            ## Name convention 2: if the model name starts with number, 
            ## the arch name is in the middle of the model name
            this = re.findall('[0-9]+-(.*)', df_table.loc[i, 'Model'])[0]
        except:
            arch.append(np.nan)
            raise continue_i

        for mm in models_:
            for m1 in mm:
                if this.startswith(m1):
                    arch.append(mm)

                    raise continue_i

        arch.append(np.nan)

    except ContinueI:
        continue

df_table['group'] = arch
df_table['group'] = df_table['group'].apply(lambda x: '/'.join(x))

# %%
'''Match the model name using matchtable'''
# df_all = pd.read_excel(path + '/df_all.xlsx').rename(columns = {'Unnamed: 0': 'index'}).set_index('index')
df_all['spectralnormlog'] = np.log(df_all['spectralnorm'])

df_full = []
i = 0

for df in df_accuracy:
    # Because there are duplicate Model names (on README), you cannot
    # simply use merge
    df = df.copy()
    df['modelname'] = df_table.loc[i:i+len(df)-1, 'modelname'].tolist()#temp[i:i+len(df)]
    df['group'] = df_table.loc[i:i+len(df)-1, 'group'].tolist()
    i += len(df)

    del df['Remarks']

    df = df.merge(df_all, on = 'modelname', how = 'left')

    df_full.append(df)

df_full = dict(zip(datasets, df_full))

del df

# %%
## Example: Look at the imagenet-1K model output
df_full['imagenet-1k']

# %%
'''[SETUP CELL] Start Plotting'''
#metrics = ['alpha', 'alpha_weighted', 'spectralnormlog', 'softrank', 'norm', 'norm_compound' ] #specify the ww matrics
#metrics_acc = ['Top1', 'Top5', 'Error, %', 'Pix.Acc.,%', 'mIoU,%'] #specify the test accuracy

metrics = ['alpha', 'alpha_weighted', 'spectralnormlog',  'softranklog',  'lognorm' ,'logpnorm' ] #specify the ww matrics
metrics_acc = ['Top1', 'Error, %', 'Pix.Acc.,%', 'mIoU,%'] #specify the test accuracy

num_rows = 2
num_cols = 3

# %%
# %matplotlib inline
plot_fit = True

'''Plotting by datasets'''
df_fit0 = []

for d in datasets:
    temp = df_full[d].copy()

    if len(temp) == 1:
        continue

    tacc = [c for c in metrics_acc if c in temp.columns]

    #plotloc = int(len(tacc)*len(metrics)/num_rows*100 + 10*num_cols + 1)
    plotrow = int(len(tacc)*len(metrics)/num_rows)
    plotcol = num_cols
    plotidx = 1

    if len(tacc) > 1:
        plt.figure(figsize = (12,20))
    else:
        plt.figure(figsize = (12,10))

    for ac in tacc:
        for x in metrics:
            plt.subplot(plotrow, plotcol, plotidx) #plt.subplot(plotloc)
            plt.scatter(temp[x], temp[ac])
            plt.xlabel(x)
            plt.ylabel(ac)
            plt.title('All {} pretrained models\n({}~{})'.format(d, ac, x), 
                      fontweight = 'bold')

            if plot_fit == True:
                temp = temp.dropna().reset_index(drop = True)
                this_fit = sm.OLS(temp[ac], sm.add_constant(temp[x])).fit()
                this_x = np.linspace(min(temp[x]), max(temp[x]), 1000)
                plt.plot(this_x, this_fit.predict(sm.add_constant(this_x)), linewidth = 2, color = 'orange')
                df_fit0.append([d, ac, x, this_fit.ssr/len(temp), this_fit.rsquared])
            
            #plotloc += 1
            plotidx += 1

    plt.tight_layout()

del temp
del tacc

if df_fit0 != []:
    df_fit0 = pd.DataFrame(df_fit0, columns = ['dataset', 'test accuracy', 'x variable', 'MSE', 'r^2'])

# %%
if type(df_fit0) != list:
    print(df_fit0.head(20)) #print the first 20 rows of the regression fit

# %% [markdown]
# # Drop additional NaN models that somehow went wrong here

# %%
'''Plotting by architectures within each datasets'''
groups = df_table['group'].value_counts().to_frame()

for d in datasets:
    df = df_full[d].copy()
    this_groups = df['group'].value_counts().to_frame()

    for g in this_groups[this_groups['group'] > 1].index:

        this_group = df[df['group'] == g].copy()
        this_group = this_group.reset_index(drop = True)

        tacc = [c for c in metrics_acc if c in this_group.columns]

        #plotloc = int(len(tacc)*len(metrics)/num_rows*100 + 10*num_cols + 1)
        plotrow = int(len(tacc)*len(metrics)/num_rows)
        plotcol = num_cols
        plotidx = 1

        if len(tacc) > 1:
            plt.figure(figsize = (12,20))
        else:
            plt.figure(figsize = (12,10))

        for ac in tacc:#metrics_acc:
            for x in metrics:
                plt.subplot(plotrow, plotcol, plotidx) #plt.subplot(plotloc)
                for i in range(len(this_group)):
                    plt.scatter(this_group.loc[i,x], this_group.loc[i, ac])
                plt.xlabel(x)
                plt.ylabel(ac)
                if (len(g) > 20) | (len(g) + len(d) >= 17): #To avoid overlap in title
                    plt.title('{}\nmodels pretrained on {}\n({}~{})'.format(g, d, ac, x), 
                              fontweight = 'bold', fontsize = 10)
                else:
                    plt.title('{} models pretrained on {}\n({}~{})'.format(g, d, ac, x), 
                              fontweight = 'bold')

                #plotloc += 1
                plotidx += 1

            #plt.legend(this_group['Model'], loc='center left',bbox_to_anchor=(1, 0.5))          
          
        plt.tight_layout()
            
        if len(this_group['Model']) > 12:
            plt.legend(this_group['Model'], loc='center left', ncol = 2, bbox_to_anchor=(1, 0.5))                      
        else:
            plt.legend(this_group['Model'], loc='center left', bbox_to_anchor=(1, 0.5))  

del this_groups
del this_group
del df

# %% [markdown]
# # Fit a linear regression on to the graphs from above

# %%
'''Fit a simple or polynomial on to the graph from above
ALL SIMPLE LINEAR FIT

Drop models that have less than 3 datapoints and incorrect fit

output:
-------------------
1. Plots
2. df_fit (next cell): records the X, Y, degree, SSE and MSE for the fit'''


#ply_degree = 2
df_fit = []
todelete = False
for d in datasets:
    df = df_full[d].copy()

    df.dropna(inplace=True)
    this_groups = df['group'].value_counts().to_frame()


    for g in this_groups[this_groups['group'] > 1].index:

        this_group = df[df['group'] == g].copy()
        this_group = this_group.dropna().reset_index(drop = True)
        n = len(this_group) #size

        if n <= 4:
            continue

        tacc = [c for c in metrics_acc if c in this_group.columns]

        #plotloc = int(len(tacc)*len(metrics)/num_rows*100 + 10*num_cols + 1)
        plotrow = int(len(tacc)*len(metrics)/num_rows)
        plotcol = int(num_cols)
        plotidx = 1

        if len(tacc) > 1:
            plt.figure(figsize = (12,20))
        else:
            plt.figure(figsize = (12,10))
        
        #if the size is too small, fit a linear reg; otherwise, fit a polynomial
        if n > 1000: #10: 
            this_deg = 2
        else:
            this_deg = 1
            
        for ac in tacc:#metrics_acc:
            for x in metrics:

                try:
                  plt.subplot(plotrow, plotcol, plotidx) #plt.subplot(plotloc)
                  for i in range(len(this_group)):
                      plt.scatter(this_group.loc[i,x], this_group.loc[i, ac], label = this_group.loc[i, 'modelname'])
                  plt.xlabel(x)
                  plt.ylabel(ac)
                  if len(g) > 35:
                      plt.title('{}\nmodels pretrained on {}\n({}~{})'.format(g, d, ac, x), 
                                fontweight = 'bold', fontsize = 9)
                  elif (len(g) > 20) | (len(g) + len(d) >= 17):
                      plt.title('{}\nmodels pretrained on {}\n({}~{})'.format(g, d, ac, x), 
                                fontweight = 'bold', fontsize = 10)
                  else:
                      plt.title('{} models pretrained on {}\n({}~{})'.format(g, d, ac, x), 
                                fontweight = 'bold')

                
                  # this_fit = np.polyfit(this_group[x], this_group[ac], 
                  #                       this_deg ,full = True)
                  # coef = this_fit[0]
                  this_fit = sm.OLS(this_group[ac], sm.add_constant(this_group[x])).fit()
                  if (x == 'alpha_weighted') & (this_fit.params[1] < 0):
                      todelete = True

                  coef = this_fit.params[x] #this_fit[0]
                  this_x = np.linspace(min(this_group[x]), max(this_group[x]), 50)

                  plt.plot(this_x, this_fit.predict(sm.add_constant(this_x))) ##coef[0]*this_x**2 + coef[1]*this_x + coef[2]) 

                  try:
                      this_sse = this_fit.ssr ##this_fit[1][0]
                      this_rsquared = this_fit.rsquared
                  except:
                      pass
                      # try:
                      #     this_sse = np.sum((coef[0]*this_group[x]**2 + coef[1]*this_group[x] + coef[2] - this_group[ac])**2)
                      # except:
                      #     this_sse = np.sum((coef[0]*this_group[x] + coef[1] - this_group[ac])**2)                                

                  this_arch = [d, g, ac, x, this_deg, n, this_rsquared, this_sse, this_sse/n]

                except np.linalg.LinAlgError: #does not converge
                    print("{} did not converge {}".format(d))
                    this_arch = [d, g, ac, x, this_deg, n, 'Not converge', np.nan, np.nan]

                df_fit.append(this_arch)
                #plotloc += 1
                plotidx += 1

            #plt.legend(loc='center left', bbox_to_anchor=(1, 0.5)) #this_group['Model']
        plt.tight_layout()

        if len(this_group['Model']) > 12:
            plt.legend(loc='center left', ncol = 2, bbox_to_anchor=(1, 0.5))                      
        else:
            plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  

        if todelete:
            plt.close()
            todelete = False

del df
del this_group
del this_sse

# %%
df_fit = pd.DataFrame(df_fit, columns = ['Dataset', 'Archtecture', 'Test Accuracy', 
                                          'x Variable', 'Poly Degree','# of Models', 
                                         'r^2', 'SSE', 'MSE'])
df_fit = df_fit[df_fit['# of Models'] > 2].reset_index(drop = True)
print("number of records {}".format(len(df_fit)))
df_fit.dropna(inplace=True)

df_fit

# %%
## df_fit records the X, Y, SSE, and MSE for the fit
df_fit.to_excel(path + '/' + 'df_fit.xlsx')

# %%
for x in ['r^2', 'MSE']:
    temp = df_fit.copy()
    temp = temp[temp['# of Models'] > 5].reset_index(drop = True)
    df_fitp = temp.pivot_table(values = x, columns = 'x Variable', 
                            index = ['Dataset', 'Archtecture', 'Test Accuracy'])

    print('For ' + x + ':')
    summary = df_fitp.describe()
    display(summary)
    print('===============================================')

del df_fitp

# %%
'''Between the ww metrics
with alpha_weighted'''

for d in datasets:
    temp = df_full[d].copy()
    df = temp.dropna()
    if len(temp) == 1:
        continue

    xys = list(itertools.combinations(metrics[1:],2)) #list(itertools.combinations(metrics[:1] + metrics[2:],2))
    
    if len(xys)%2 == 0:
       plotrow = int(len(xys)/2)
       plotcol = 2
       plotidx = 1
    elif len(xys)%3 == 0:
       plotrow = int(len(xys)/3)
       plotcol = 3
       plotidx = 1

    plt.figure(figsize = (12, 3*plotrow))
    for x, y in xys: #tertools.combinations(metrics[:1] + metrics[2:],2):
        plt.subplot(plotrow, plotcol, plotidx) #plt.subplot(plotloc)
        plt.scatter(df[x], df[y])
        plt.xlabel(x)
        plt.ylabel(y)
        plt.title('All {} pretrained models\n({}~{})'.format(d, y, x), 
                  fontweight = 'bold')
        #plt.figure(figsize = (10,10))
        #plt.show()

        #plotloc += 1
        plotidx += 1
    
    plt.tight_layout()

del temp

# %% [markdown]
# ## Analysis of *VGG*

# %%
df = df_full['imagenet-1k'].copy()
vgg_df = df[df.Model.str.contains('VGG')]
display(vgg_df)
# Out:
#          Model   Top1   Top5  ...  spectralnorm_compound index spectralnormlog
# 4       VGG-11  29.90  10.36  ...              22.276894   5.0        3.111649
# 5       VGG-13  28.76   9.75  ...              19.301830   6.0        2.932049
# 6       VGG-16  26.98   8.65  ...              16.813160   7.0        2.808524
# 7       VGG-19  25.74   7.90  ...              22.353643   8.0        3.044657
# 8    BN-VGG-11  29.01   9.61  ...              18.135994   9.0        2.916182
# 9    BN-VGG-13  27.83   9.13  ...              16.671089  10.0        2.810087
# 10   BN-VGG-16  25.72   7.79  ...              15.994361  11.0        2.763428
# 11   BN-VGG-19  24.13   7.12  ...              14.629992  12.0        2.674925
# 12  BN-VGG-11b  29.56   9.96  ...              27.851130  13.0        3.244067
# 13  BN-VGG-13b  28.41   9.63  ...              25.033779  14.0        3.125851
# 14  BN-VGG-16b  27.19   8.74  ...              20.271507  15.0        2.911069
# 15  BN-VGG-19b  26.06   8.40  ...              17.819702  16.0        2.765158
#
# [12 rows x 33 columns]

# %%
display(vgg_df[['Model', 'Top1', 'alpha', 'norm', 'alpha_weighted']].sort_values('Top1').reset_index(drop = True))
# Out:
#          Model   Top1     alpha       norm  alpha_weighted
# 0    BN-VGG-19  24.13  3.372452  16.369974        3.796408
# 1    BN-VGG-16  25.72  3.211754  16.749430        3.766603
# 2       VGG-19  25.74  3.050589  19.586618        4.001597
# 3   BN-VGG-19b  26.06  3.202934  17.981234        3.830761
# 4       VGG-16  26.98  2.946369  17.114365        3.506696
# 5   BN-VGG-16b  27.19  3.025120  18.566490        3.833127
# 6    BN-VGG-13  27.83  3.026542  16.897371        3.636423
# 7   BN-VGG-13b  28.41  2.953078  18.682676        3.947539
# 8       VGG-13  28.76  2.672990  17.123001        3.257229
# 9    BN-VGG-11  29.01  2.812567  18.735483        3.587930
# 10  BN-VGG-11b  29.56  2.746966  20.929249        3.785228
# 11      VGG-11  29.90  2.718865  19.289885        3.481365

# %%
vgg_df.plot(x='Top1', y= 'alpha', kind='scatter')
vgg_df.plot(x='Top1', y= 'softrank', kind='scatter')
vgg_df.plot(x='Top1', y= 'norm', kind='scatter')
vgg_df.plot(x='Top1', y= 'alpha_weighted', kind='scatter')

# %% [markdown]
# ## **HuggingFace Models**

# %% [markdown]
# ### **1. Analyze all models using Weightwatcher**

# %%
# !pip install pytorch-transformers

# %%
import pytorch_transformers as pt
import torch

# %%
hf_models = pd.read_html('https://huggingface.co/pytorch-transformers/pretrained_models.html')[0]
hf_models.head()
# Out:
#   Architecture  ...                               Details of the model
# 0         BERT  ...  12-layer, 768-hidden, 12-heads, 110M parameter...
# 1         BERT  ...  24-layer, 1024-hidden, 16-heads, 340M paramete...
# 2         BERT  ...  12-layer, 768-hidden, 12-heads, 110M parameter...
# 3         BERT  ...  24-layer, 1024-hidden, 16-heads, 340M paramete...
# 4         BERT  ...  (Original, not recommended) 12-layer, 768-hidd...
#
# [5 rows x 3 columns]

# %%
# PyTorch-Transformers has a unified API
# for 7 transformer architectures and 30 pretrained weights.
#          Model              | Tokenizer             | Pretrained weights shortcuts
MODELS = [(pt.BertModel,       pt.BertTokenizer,       hf_models.loc[hf_models['Architecture'] == 'BERT', 'Shortcut name'].tolist()),
          (pt.OpenAIGPTModel,  pt.OpenAIGPTTokenizer,  hf_models.loc[hf_models['Architecture'] == 'GPT', 'Shortcut name'].tolist()),
          (pt.GPT2Model,       pt.GPT2Tokenizer,       hf_models.loc[hf_models['Architecture'] == 'GPT-2', 'Shortcut name'].tolist()),
          (pt.TransfoXLModel,  pt.TransfoXLTokenizer,  hf_models.loc[hf_models['Architecture'] == 'Transformer-XL', 'Shortcut name'].tolist()),
          (pt.XLNetModel,      pt.XLNetTokenizer,      hf_models.loc[hf_models['Architecture'] == 'XLNet', 'Shortcut name'].tolist()),
          (pt.XLMModel,        pt.XLMTokenizer,        hf_models.loc[hf_models['Architecture'] == 'XLM', 'Shortcut name'].tolist()),
          (pt.RobertaModel,    pt.RobertaTokenizer,    hf_models.loc[hf_models['Architecture'] == 'RoBERTa', 'Shortcut name'].tolist()),
          (pt.DistilBertModel, pt.DistilBertTokenizer, hf_models.loc[hf_models['Architecture'] == 'DistilBERT', 'Shortcut name'].tolist())]

# %%
'''Run the HuggingFace Models'''
data_hf = {}
i = 0
for model_class, tokenizer_class, pretrained_weights in MODELS[6:]:
    # Load pretrained model/tokenizer
    #tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
    
    for m in pretrained_weights:
        
        if (m == 'roberta-base') | (m == 'roberta-large'):
            continue
            
        s = time.time()
        model = model_class.from_pretrained(m)
        
        ## apply ww
        watcher = ww.WeightWatcher(model=model, logger=logger)
        results = watcher.analyze(alphas = True, spectralnorms=True, softranks=True)
        
        data_hf[m]=watcher.get_summary()
        e = time.time()
        
        print('\nTime spent to run {} model is {} minutes'.format(m, (e-s)/60.))
        print('----------------------------------------------------------------')
        
        df_hf = pd.DataFrame.from_dict(data_hf).transpose()
        df_hf.to_excel('/content/drive/My Drive/data_hf_{}.xlsx'.format(m))

        i += 0

# %%
try:
    df_hugging = pd.read_excel(path + '/df_hugging.xlsx')\
                .rename(columns = {'Unnamed: 0': 'Architecture'})
    df_hugging['Architecture'] = df_hugging['Architecture'].fillna(method = 'ffill')
except:
    print("Concating...")
    df_hugging = pd.DataFrame()
    for f in os.listdir(path):
        if f.startswith('data_hf'):
            temp = pd.read_excel(path + '/' + f)\
                        .rename(columns = {'Unnamed: 0':'modelname'})
            print(f)
            df_hugging = pd.concat([df_hugging, temp], axis = 0, sort = False)

    df_hugging = df_hugging.drop_duplicates().reset_index(drop = True)

    df_hugging = df_hugging.merge(hf_models.loc[:, ['Architecture',	'Shortcut name']],
                                  left_on = 'modelname', right_on = 'Shortcut name',
                                  how = 'left').drop(['Shortcut name'], axis = 1)

    df_hugging = df_hugging[['Architecture'] + df_hugging.columns[:-1].tolist()]

    del temp

    df_hugging = df_hugging.set_index(['modelname'])
    df_hugging = df_hugging.loc[hf_models['Shortcut name'],:].reset_index()

    df_hugging.to_excel(path + '/df_hugging.xlsx')

# if len(df_hugging) != len(hf_models):
#     print('Missing models')

df_hugging.head()
# Out:
#   Architecture  ... spectralnorm_compound
# 0         Bert  ...            420.008881
# 1         Bert  ...            211.702621
# 2         Bert  ...            149.275208
# 3         Bert  ...            171.152267
# 4         Bert  ...            257.559631
#
# [5 rows x 18 columns]

# %% [markdown]
# ### **2. Plots**

# %%
## Barplot for all archtectures
try:
    df_hugging
except:
    df_hugging = pd.read_excel(path + '/df_hugging.xlsx')\
                .rename(columns = {'Unnamed: 0': 'Architecture'})
    df_hugging['Architecture'] = df_hugging['Architecture'].fillna(method = 'ffill')

metrics = ['alpha', 'alpha_weighted', 'spectralnormlog', 'softrank']
df_hugging['spectralnormlog'] = np.log(df_hugging['spectralnorm'])

for m in metrics:
    plt.figure(figsize = (10,15))
    df_hugging.plot.barh(x = 'modelname', y = m, figsize = (10,15))
    plt.title('Barplot for all architectures in hugging face: {}'.format(m), fontweight = 'bold', fontsize = 15)
    plt.legend([m], fontsize = 15)

# %%
## Scatter plot for other metrics
temp = df_hugging.copy()

for x, y in itertools.combinations(metrics[:1] + metrics[2:],2):
    plt.figure(figsize = (8, 6))
    for i in range(len(df_hugging)):
        plt.scatter(temp.loc[i, x], temp.loc[i, y], label = temp.loc[i, 'modelname'])
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title('All HuggingFace models\n({}~{})'.format(y, x), 
              fontweight = 'bold')  
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=2)  

    
del temp
